# %%
import matplotlib.pyplot as plt

hash_max = 30 
hash = list(range(hash_max))

# %%
result1 = [0.000, 0.000, 0.000, 0.016, 0.168, 0.472, 0.734, 0.888, 0.958, 0.980, 0.993, 0.998, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000]
result2 = [0.000, 0.000, 0.000, 0.000, 0.006, 0.114, 0.367, 0.631, 0.795, 0.896, 0.941, 0.971, 0.983, 0.990, 0.995, 0.997, 0.998, 0.999, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000]
plt.plot(hash, result1, marker='o', label='(a)')
plt.plot(hash, result2, marker='x', label='(b)')
plt.xlabel("hash")
plt.ylabel("probability of success")
plt.legend() 
plt.show()

# %%
result1 = [0.000, 0.000, 0.000, 0.016, 0.168, 0.472, 0.734, 0.888, 0.958, 0.980, 0.993, 0.998, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000]
plt.plot(hash, result1, marker='o', label='(a)')
plt.xlabel("hash")
plt.ylabel("probability of success")
plt.legend() 
plt.show()
